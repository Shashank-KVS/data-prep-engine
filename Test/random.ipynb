# %%
pip install data-prep-engine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from data_prep_engine import AutoPrep
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from data_prep_engine import AutoPrep
#
# ImportError: cannot import name 'AutoPrep' from 'data_prep_engine' (/Users/shashankkv/Desktop/Projects/PYPI-Lib/Test/test/lib/python3.13/site-packages/data_prep_engine/__init__.py)
