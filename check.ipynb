# %%
from data_prep_engine import AutoPrep

# %%
prep = AutoPrep.default()
result = prep.run_from_uri("/Users/shashankkv/Desktop/Projects/PYPI-Lib/data.csv")

result.cleaned_table.to_pandas().head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 prep = AutoPrep.default()
# ----> 2 result = prep.run_from_uri("/Users/shashankkv/Desktop/Projects/PYPI-Lib/data.csv")
#       4 result.cleaned_table.to_pandas().head()
#
# File ~/Desktop/Projects/PYPI-Lib/Test/test/lib/python3.13/site-packages/data_prep_engine/autoprep.py:77, in AutoPrep.run_from_uri(self, uri, format_hint)
#      67 """
#      68 Full pipeline starting from a URI.
#      69
#    (...)     74 4. Diagnose after cleaning
#      75 """
#      76 raw_table = self.loader.load(uri, format_hint=format_hint)
# ---> 77 return self.run_from_table(raw_table)
#
# File ~/Desktop/Projects/PYPI-Lib/Test/test/lib/python3.13/site-packages/data_prep_engine/autoprep.py:83, in AutoPrep.run_from_table(self, table)
#      79 def run_from_table(self, table: StandardTable) -> AutoPrepResult:
# ...
